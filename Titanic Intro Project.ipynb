# %%
import pandas as pd
from pandas import Series, DataFrame
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-2-6f5539a2fa70> in <module>()
# ----> 1 import pandas as pd
#       2 from pandas import Series, DataFrame
#
# ModuleNotFoundError: No module named 'pandas'

# %%
titanic_df = pd.read_csv('/Users/xucc/Downloads/train.csv')

# %%
titanic_df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
titanic_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
# PassengerId    891 non-null int64
# Survived       891 non-null int64
# Pclass         891 non-null int64
# Name           891 non-null object
# Sex            891 non-null object
# Age            714 non-null float64
# SibSp          891 non-null int64
# Parch          891 non-null int64
# Ticket         891 non-null object
# Fare           891 non-null float64
# Cabin          204 non-null object
# Embarked       889 non-null object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 83.6+ KB

# %%
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
sns.factorplot('Sex', data = titanic_df)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-28-2c68742d212a> in <module>()
# ----> 1 sns.factorplot('Sex', data = titanic_df)
#
# /Users/xucc/anaconda/lib/python2.7/site-packages/seaborn/categorical.pyc in factorplot(x, y, hue, data, row, col, col_wrap, estimator, ci, n_boot, units, order, hue_order, row_order, col_order, kind, size, aspect, orient, color, palette, legend, legend_out, sharex, sharey, margin_titles, facet_kws, **kwargs)
#    3428
#    3429     Use a different color palette:
# -> 3430
#    3431     .. plot::
#    3432         :context: close-figs
#
# /Users/xucc/anaconda/lib/python2.7/site-packages/seaborn/axisgrid.pyc in map_dataframe(self, func, *args, **kwargs)
#     792             # Decide what color to plot with
#     793             kwargs["color"] = self._facet_color(hue_k, kw_color)
# --> 794
# ...

# %%
sns.factorplot('Sex', data = titanic_df, hue = 'Pclass')
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-11-c39aac4955c1> in <module>()
# ----> 1 sns.factorplot('Sex', data = titanic_df, hue = 'Pclass')
#
# /Users/xucc/anaconda/lib/python2.7/site-packages/seaborn/categorical.pyc in factorplot(x, y, hue, data, row, col, col_wrap, estimator, ci, n_boot, units, order, hue_order, row_order, col_order, kind, size, aspect, orient, color, palette, legend, legend_out, sharex, sharey, margin_titles, facet_kws, **kwargs)
#    3428
#    3429     # Draw the plot onto the facets
# -> 3430     g.map_dataframe(plot_func, x, y, hue, **plot_kws)
#    3431
#    3432     # Special case axis labels for a count type plot
#
# /Users/xucc/anaconda/lib/python2.7/site-packages/seaborn/axisgrid.pyc in map_dataframe(self, func, *args, **kwargs)
#     792
#     793             # Draw the plot
# ...

# %%
def male_female_child(passager):
    age, sex = passenger
    if age<16:
        return 'child'
    else:
        return sex

# %%
titanic_df[['Age', 'Sex']]
# Out:
#       Age     Sex
# 0    22.0    male
# 1    38.0  female
# 2    26.0  female
# 3    35.0  female
# 4    35.0    male
# 5     NaN    male
# 6    54.0    male
# 7     2.0    male
# 8    27.0  female
# 9    14.0  female
# 10    4.0  female
# 11   58.0  female
# 12   20.0    male
# 13   39.0    male
# 14   14.0  female
# 15   55.0  female
# 16    2.0    male
# 17    NaN    male
# 18   31.0  female
# 19    NaN  female
# 20   35.0    male
# 21   34.0    male
# 22   15.0  female
# 23   28.0    male
# 24    8.0  female
# 25   38.0  female
# 26    NaN    male
# 27   19.0    male
# 28    NaN  female
# 29    NaN    male
# ..    ...     ...
# 861  21.0    male
# 862  48.0  female
# 863   NaN  female
# 864  24.0    male
# 865  42.0  female
# 866  27.0  female
# 867  31.0    male
# 868   NaN    male
# 869   4.0    male
# 870  26.0    male
# 871  47.0  female
# 872  33.0    male
# 873  47.0    male
# 874  28.0  female
# 875  15.0  female
# 876  20.0    male
# 877  19.0    male
# 878   NaN    male
# ...

# %%
titanic_df[['Age', 'Sex']].apply(male_female_child)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-34-93e30a48fe39> in <module>()
# ----> 1 titanic_df[['Age', 'Sex']].apply(male_female_child)
#
# /Users/xucc/anaconda/lib/python2.7/site-packages/pandas/core/frame.pyc in apply(self, func, axis, broadcast, raw, reduce, args, **kwds)
#    4358                         f, axis,
#    4359                         reduce=reduce,
# -> 4360                         ignore_failures=ignore_failures)
#    4361             else:
#    4362                 return self._apply_broadcast(f, axis)
#
# /Users/xucc/anaconda/lib/python2.7/site-packages/pandas/core/frame.pyc in _apply_standard(self, func, axis, ignore_failures, reduce)
#    4454             try:
#    4455                 for i, v in enumerate(series_gen):
# -> 4456                     results[i] = func(v)
#    4457                     keys.append(v.name)
# ...

# %%
titanic_df['Age'].mean()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-0ef6aa03bab5> in <module>()
# ----> 1 titanic_df['Age'].mean()
#
# NameError: name 'titanic_df' is not defined

# %%
titanic_df['person'].value_counts()

# %%
sns.factorplot('Sex',data=titanic_df)

# %%
plt.bar(titanic_df["Sex"],histogram.values())
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-32-f4dad7eea44e> in <module>()
# ----> 1 plt.bar(titanic_df["Sex"],histogram.values())
#
# NameError: name 'histogram' is not defined

# %%
plt.bar([],titanic_df["Sex"].value_counts())
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-33-813ee2511b93> in <module>()
# ----> 1 plt.bar(titanic_df["Sex"],titanic_df["Sex"].value_counts())
#
# /Users/xucc/anaconda/lib/python2.7/site-packages/matplotlib/pyplot.pyc in bar(left, height, width, bottom, hold, data, **kwargs)
#    2702     try:
#    2703         ret = ax.bar(left, height, width=width, bottom=bottom, data=data,
# -> 2704                      **kwargs)
#    2705     finally:
#    2706         ax._hold = washold
#
# /Users/xucc/anaconda/lib/python2.7/site-packages/matplotlib/__init__.pyc in inner(ax, *args, **kwargs)
#    1896                     warnings.warn(msg % (label_namer, func.__name__),
#    1897                                   RuntimeWarning, stacklevel=2)
# -> 1898             return func(ax, *args, **kwargs)
#    1899         pre_doc = inner.__doc__
# ...

# %%
titanic_df["Sex"].value_counts()
# Out:
# male      577
# female    314
# Name: Sex, dtype: int64

# %%
titanic_df["Sex"].values
# Out:
# array(['male', 'female', 'female', 'female', 'male', 'male', 'male',
#        'male', 'female', 'female', 'female', 'female', 'male', 'male',
#        'female', 'female', 'male', 'male', 'female', 'female', 'male',
#        'male', 'female', 'male', 'female', 'female', 'male', 'male',
#        'female', 'male', 'male', 'female', 'female', 'male', 'male',
#        'male', 'male', 'male', 'female', 'female', 'female', 'female',
#        'male', 'female', 'female', 'male', 'male', 'female', 'male',
#        'female', 'male', 'male', 'female', 'female', 'male', 'male',
#        'female', 'male', 'female', 'male', 'male', 'female', 'male',
#        'male', 'male', 'male', 'female', 'male', 'female', 'male', 'male',
#        'female', 'male', 'male', 'male', 'male', 'male', 'male', 'male',
#        'female', 'male', 'male', 'female', 'male', 'female', 'female',
#        'male', 'male', 'female', 'male', 'male', 'male', 'male', 'male',
# ...
